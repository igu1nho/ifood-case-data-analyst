# %% [markdown]
# # Predictive model for classification

# %%
import pandas as pd

DATA = "../data/customers_clustered.csv"

df_clustered = pd.read_csv(DATA)
df_clustered.head()
# Out:
#     Education Marital_Status   Income  Kidhome  Teenhome  Recency  MntWines  \
# 0  Graduation         Single  58138.0        0         0       58       635
# 1  Graduation         Single  46344.0        1         1       38        11
# 2  Graduation        Partner  71613.0        0         0       26       426
# 3  Graduation        Partner  26646.0        1         0       26        11
# 4         PhD        Partner  58293.0        1         0       94       173
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  Age  AgeGroup  MntTotal  \
# 0         88              546              172  ...   57     46-60      1617
# 1          1                6                2  ...   60     46-60        27
# 2         49              127              111  ...   49     46-60       776
# 3          4               20               10  ...   30     18-30        53
# 4         43              118               46  ...   33     31-45       422
#
#    MntRegularProds  Children  HasChildren  AcceptedCmpTotal  HasAcceptedCmp  \
# 0             1529         0            0                 0               0
# 1               21         2            1                 0               0
# 2              734         0            0                 0               0
# 3               48         1            1                 0               0
# 4              407         1            1                 0               0
#
#    NumTotalPurchases  cluster
# 0                 22        0
# 1                  4        1
# 2                 20        0
# 3                  6        1
# 4                 14        2
#
# [5 rows x 36 columns]

# %%
df_clustered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2205 non-null   object
#  1   Marital_Status       2205 non-null   object
#  2   Income               2205 non-null   float64
#  3   Kidhome              2205 non-null   int64
#  4   Teenhome             2205 non-null   int64
#  5   Recency              2205 non-null   int64
#  6   MntWines             2205 non-null   int64
#  7   MntFruits            2205 non-null   int64
#  8   MntMeatProducts      2205 non-null   int64
#  9   MntFishProducts      2205 non-null   int64
#  10  MntSweetProducts     2205 non-null   int64
#  11  MntGoldProds         2205 non-null   int64
#  12  NumDealsPurchases    2205 non-null   int64
#  13  NumWebPurchases      2205 non-null   int64
#  14  NumCatalogPurchases  2205 non-null   int64
#  15  NumStorePurchases    2205 non-null   int64
#  16  NumWebVisitsMonth    2205 non-null   int64
#  17  AcceptedCmp3         2205 non-null   int64
#  18  AcceptedCmp4         2205 non-null   int64
#  19  AcceptedCmp5         2205 non-null   int64
#  20  AcceptedCmp1         2205 non-null   int64
#  21  AcceptedCmp2         2205 non-null   int64
#  22  Complain             2205 non-null   int64
#  23  Response             2205 non-null   int64
#  24  DaysSinceEnrolled    2205 non-null   int64
#  25  YearsSinceEnrolled   2205 non-null   int64
#  26  Age                  2205 non-null   int64
#  27  AgeGroup             2205 non-null   object
#  28  MntTotal             2205 non-null   int64
#  29  MntRegularProds      2205 non-null   int64
#  30  Children             2205 non-null   int64
#  31  HasChildren          2205 non-null   int64
#  32  AcceptedCmpTotal     2205 non-null   int64
#  33  HasAcceptedCmp       2205 non-null   int64
#  34  NumTotalPurchases    2205 non-null   int64
#  35  cluster              2205 non-null   int64
# dtypes: float64(1), int64(32), object(3)
# memory usage: 620.3+ KB

# %%
X = df_clustered.drop("Response", axis=1)
y = df_clustered["Response"]

# %%
X.head()
# Out:
#     Education Marital_Status   Income  Kidhome  Teenhome  Recency  MntWines  \
# 0  Graduation         Single  58138.0        0         0       58       635
# 1  Graduation         Single  46344.0        1         1       38        11
# 2  Graduation        Partner  71613.0        0         0       26       426
# 3  Graduation        Partner  26646.0        1         0       26        11
# 4         PhD        Partner  58293.0        1         0       94       173
#
#    MntFruits  MntMeatProducts  MntFishProducts  ...  Age  AgeGroup  MntTotal  \
# 0         88              546              172  ...   57     46-60      1617
# 1          1                6                2  ...   60     46-60        27
# 2         49              127              111  ...   49     46-60       776
# 3          4               20               10  ...   30     18-30        53
# 4         43              118               46  ...   33     31-45       422
#
#    MntRegularProds  Children  HasChildren  AcceptedCmpTotal  HasAcceptedCmp  \
# 0             1529         0            0                 0               0
# 1               21         2            1                 0               0
# 2              734         0            0                 0               0
# 3               48         1            1                 0               0
# 4              407         1            1                 0               0
#
#    NumTotalPurchases  cluster
# 0                 22        0
# 1                  4        1
# 2                 20        0
# 3                  6        1
# 4                 14        2
#
# [5 rows x 35 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Response, dtype: int64

# %%
one_hot_cols = [
    "Education",
    "Marital_Status",
    "AgeGroup",
    "HasChildren",
    "HasAcceptedCmp",
    "AcceptedCmp1",
    "AcceptedCmp2",
    "AcceptedCmp3",
    "AcceptedCmp4",
    "AcceptedCmp5",
    "Complain",
    "Kidhome",
    "Teenhome",
    "YearsSinceEnrolled",
    "Children",
    "AcceptedCmpTotal",
    "cluster"
]

standard_cols = [
    "Income",
    "Age",
]

power_cols = X.columns[
   X.columns.str.startswith("Mnt") | X.columns.str.startswith("Num")
].tolist()

minmax_cols = [
    col for col in X.columns if col not in one_hot_cols + standard_cols + power_cols
]

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html

# %%
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler,
    MinMaxScaler,
    PowerTransformer,
)
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from imblearn.pipeline import Pipeline  # atenção para o Pipeline do ImbLearn
from sklearn.feature_selection import SelectKBest, f_classif
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import cross_validate

RANDOM_STATE = 42

models = {
    "DummyClassifier": DummyClassifier(
        strategy="stratified", random_state=RANDOM_STATE
    ),
    "DecisionTreeClassifier": DecisionTreeClassifier(random_state=RANDOM_STATE),
    "LogisticRegression": LogisticRegression(random_state=RANDOM_STATE),
    "KNNClassifier": KNeighborsClassifier(n_neighbors=5),
}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)


def pipeline_model(X, y, model, kf):
    preprocessing = ColumnTransformer(
        [
            ("one-hot", OneHotEncoder(), one_hot_cols),
            ("standard", StandardScaler(), standard_cols),
            ("minmax", MinMaxScaler(), minmax_cols),
            ("power", PowerTransformer(), power_cols),
        ]
    )

    pipeline = Pipeline(
        [
            ("preprocessing", preprocessing),
            ("feature_selection", SelectKBest(score_func=f_classif, k=10)),
            ("rus", RandomUnderSampler(random_state=RANDOM_STATE)),
            ("model", model),
        ]
    )

    scores = cross_validate(
        pipeline,
        X,
        y,
        cv=kf,
        scoring=["accuracy", "precision", "recall", "roc_auc", "average_precision"],
        n_jobs=-1,
    )

    return scores

# %%
results = {
    "DummyClassifier": pipeline_model(X, y, models["DummyClassifier"], skf),
    "DecisionTreeClassifier": pipeline_model(X, y, models["DecisionTreeClassifier"], skf),
    "LogisticRegression": pipeline_model(X, y, models["LogisticRegression"], skf),
    "KNNClassifier": pipeline_model(X, y, models["KNNClassifier"], skf),
}

# %%
from pprint import pprint

pprint(results)
# Out:
# {'DecisionTreeClassifier': {'fit_time': array([0.02625394, 0.02990675, 0.02816963, 0.02818131, 0.02720451]),
#                             'score_time': array([0.0112834 , 0.01197362, 0.01233888, 0.01140642, 0.01227212]),
#                             'test_accuracy': array([0.82539683, 0.82993197, 0.82993197, 0.81179138, 0.6893424 ]),
#                             'test_average_precision': array([0.3683831 , 0.38016844, 0.3602606 , 0.43117226, 0.22619856]),
#                             'test_precision': array([0.43243243, 0.44444444, 0.44871795, 0.40229885, 0.26797386]),
#                             'test_recall': array([0.47761194, 0.47761194, 0.52238806, 0.53030303, 0.62121212]),
#                             'test_roc_auc': array([0.68534999, 0.70773805, 0.73826722, 0.71830303, 0.66331313])},
#  'DummyClassifier': {'fit_time': array([0.03378677, 0.02707887, 0.02874303, 0.02851009, 0.02742219]),
#                      'score_time': array([0.01154971, 0.01189637, 0.01439571, 0.01173377, 0.01460433]),
#                      'test_accuracy': array([0.51247166, 0.50340136, 0.50340136, 0.48752834, 0.51020408]),
#                      'test_average_precision': array([0.15304952, 0.14865734, 0.14865734, 0.14004965, 0.14959821]),
#                      'test_precision': array([0.15420561, 0.14485981, 0.14485981, 0.12616822, 0.14953271]),
#                      'test_recall': array([0.49253731, 0.46268657, 0.46268657, 0.40909091, 0.48484848]),
#                      'test_roc_auc': array([0.50429005, 0.48669088, 0.48669088, 0.45521212, 0.49975758])},
#  'KNNClassifier': {'fit_time': array([0.02618074, 0.03906965, 0.03857684, 0.04171848, 0.04063916]),
#                    'score_time': array([0.01448989, 0.02172756, 0.02088475, 0.01890326, 0.01978397]),
#                    'test_accuracy': array([0.85034014, 0.85260771, 0.85487528, 0.87528345, 0.73696145]),
#                    'test_average_precision': array([0.28352581, 0.3012184 , 0.25258946, 0.36341931, 0.37904536]),
#                    'test_precision': array([0.51724138, 0.53333333, 0.56521739, 0.82352941, 0.33108108]),
#                    'test_recall': array([0.2238806 , 0.23880597, 0.19402985, 0.21212121, 0.74242424]),
#                    'test_roc_auc': array([0.60130497, 0.60300104, 0.60617368, 0.64371717, 0.77177778])},
#  'LogisticRegression': {'fit_time': array([0.04539156, 0.04644966, 0.0448277 , 0.04477978, 0.03748465]),
#                         'score_time': array([0.01616216, 0.01441383, 0.01627326, 0.01575398, 0.01540828]),
#                         'test_accuracy': array([0.7845805 , 0.82993197, 0.82993197, 0.81405896, 0.83673469]),
#                         'test_average_precision': array([0.38198141, 0.41502673, 0.36325137, 0.40981808, 0.50652827]),
#                         'test_precision': array([0.35106383, 0.44444444, 0.45      , 0.40909091, 0.46666667]),
#                         'test_recall': array([0.49253731, 0.47761194, 0.53731343, 0.54545455, 0.63636364]),
#                         'test_roc_auc': array([0.68570915, 0.70831671, 0.73858648, 0.71888889, 0.79476768])}}

# %%
for k, v in results.items():
    results[k]["time"] = results[k]["fit_time"] + results[k]["score_time"]

pprint(results)
# Out:
# {'DecisionTreeClassifier': {'fit_time': array([0.02625394, 0.02990675, 0.02816963, 0.02818131, 0.02720451]),
#                             'score_time': array([0.0112834 , 0.01197362, 0.01233888, 0.01140642, 0.01227212]),
#                             'test_accuracy': array([0.82539683, 0.82993197, 0.82993197, 0.81179138, 0.6893424 ]),
#                             'test_average_precision': array([0.3683831 , 0.38016844, 0.3602606 , 0.43117226, 0.22619856]),
#                             'test_precision': array([0.43243243, 0.44444444, 0.44871795, 0.40229885, 0.26797386]),
#                             'test_recall': array([0.47761194, 0.47761194, 0.52238806, 0.53030303, 0.62121212]),
#                             'test_roc_auc': array([0.68534999, 0.70773805, 0.73826722, 0.71830303, 0.66331313]),
#                             'time': array([0.03753734, 0.04188037, 0.04050851, 0.03958774, 0.03947663])},
#  'DummyClassifier': {'fit_time': array([0.03378677, 0.02707887, 0.02874303, 0.02851009, 0.02742219]),
#                      'score_time': array([0.01154971, 0.01189637, 0.01439571, 0.01173377, 0.01460433]),
#                      'test_accuracy': array([0.51247166, 0.50340136, 0.50340136, 0.48752834, 0.51020408]),
#                      'test_average_precision': array([0.15304952, 0.14865734, 0.14865734, 0.14004965, 0.14959821]),
#                      'test_precision': array([0.15420561, 0.14485981, 0.14485981, 0.12616822, 0.14953271]),
#                      'test_recall': array([0.49253731, 0.46268657, 0.46268657, 0.40909091, 0.48484848]),
#                      'test_roc_auc': array([0.50429005, 0.48669088, 0.48669088, 0.45521212, 0.49975758]),
#                      'time': array([0.04533648, 0.03897524, 0.04313874, 0.04024386, 0.04202652])},
#  'KNNClassifier': {'fit_time': array([0.02618074, 0.03906965, 0.03857684, 0.04171848, 0.04063916]),
#                    'score_time': array([0.01448989, 0.02172756, 0.02088475, 0.01890326, 0.01978397]),
#                    'test_accuracy': array([0.85034014, 0.85260771, 0.85487528, 0.87528345, 0.73696145]),
#                    'test_average_precision': array([0.28352581, 0.3012184 , 0.25258946, 0.36341931, 0.37904536]),
#                    'test_precision': array([0.51724138, 0.53333333, 0.56521739, 0.82352941, 0.33108108]),
#                    'test_recall': array([0.2238806 , 0.23880597, 0.19402985, 0.21212121, 0.74242424]),
#                    'test_roc_auc': array([0.60130497, 0.60300104, 0.60617368, 0.64371717, 0.77177778]),
#                    'time': array([0.04067063, 0.06079721, 0.05946159, 0.06062174, 0.06042314])},
#  'LogisticRegression': {'fit_time': array([0.04539156, 0.04644966, 0.0448277 , 0.04477978, 0.03748465]),
#                         'score_time': array([0.01616216, 0.01441383, 0.01627326, 0.01575398, 0.01540828]),
#                         'test_accuracy': array([0.7845805 , 0.82993197, 0.82993197, 0.81405896, 0.83673469]),
#                         'test_average_precision': array([0.38198141, 0.41502673, 0.36325137, 0.40981808, 0.50652827]),
#                         'test_precision': array([0.35106383, 0.44444444, 0.45      , 0.40909091, 0.46666667]),
#                         'test_recall': array([0.49253731, 0.47761194, 0.53731343, 0.54545455, 0.63636364]),
#                         'test_roc_auc': array([0.68570915, 0.70831671, 0.73858648, 0.71888889, 0.79476768]),
#                         'time': array([0.06155372, 0.06086349, 0.06110096, 0.06053376, 0.05289292])}}

# %%
df_results = pd.DataFrame(results).T.reset_index().rename(columns={"index": "model"})
df_results
# Out:
#                     model                                           fit_time  \
# 0         DummyClassifier  [0.033786773681640625, 0.027078866958618164, 0...
# 1  DecisionTreeClassifier  [0.026253938674926758, 0.029906749725341797, 0...
# 2      LogisticRegression  [0.04539155960083008, 0.04644966125488281, 0.0...
# 3           KNNClassifier  [0.026180744171142578, 0.03906965255737305, 0....
#
#                                           score_time  \
# 0  [0.011549711227416992, 0.011896371841430664, 0...
# 1  [0.011283397674560547, 0.01197361946105957, 0....
# 2  [0.01616215705871582, 0.014413833618164062, 0....
# 3  [0.014489889144897461, 0.021727561950683594, 0...
#
#                                        test_accuracy  \
# 0  [0.5124716553287982, 0.5034013605442177, 0.503...
# 1  [0.8253968253968254, 0.8299319727891157, 0.829...
# 2  [0.7845804988662132, 0.8299319727891157, 0.829...
# 3  [0.8503401360544217, 0.8526077097505669, 0.854...
#
#                                       test_precision  \
# 0  [0.1542056074766355, 0.14485981308411214, 0.14...
# 1  [0.43243243243243246, 0.4444444444444444, 0.44...
# 2  [0.35106382978723405, 0.4444444444444444, 0.45...
# 3  [0.5172413793103449, 0.5333333333333333, 0.565...
#
#                                          test_recall  \
# 0  [0.4925373134328358, 0.4626865671641791, 0.462...
# 1  [0.47761194029850745, 0.47761194029850745, 0.5...
# 2  [0.4925373134328358, 0.47761194029850745, 0.53...
# 3  [0.22388059701492538, 0.23880597014925373, 0.1...
#
#                                         test_roc_auc  \
# 0  [0.5042900470907494, 0.4866908771649773, 0.486...
# 1  [0.6853499880277755, 0.7077380477292681, 0.738...
# 2  [0.6857091547609545, 0.7083167052438343, 0.738...
# 3  [0.6013049724638838, 0.6030010375927847, 0.606...
#
#                               test_average_precision  \
# 0  [0.15304952129175473, 0.14865734269715697, 0.1...
# 1  [0.3683830979533475, 0.38016844076749257, 0.36...
# 2  [0.3819814120613085, 0.41502673077110863, 0.36...
# 3  [0.2835258077353654, 0.3012183978068839, 0.252...
#
#                                                 time
# 0  [0.04533648490905762, 0.03897523880004883, 0.0...
# 1  [0.037537336349487305, 0.04188036918640137, 0....
# 2  [0.0615537166595459, 0.060863494873046875, 0.0...
# 3  [0.04067063331604004, 0.06079721450805664, 0.0...

# %%
df_results.columns[1:].to_list()
# Out:
# ['fit_time',
#  'score_time',
#  'test_accuracy',
#  'test_precision',
#  'test_recall',
#  'test_roc_auc',
#  'test_average_precision',
#  'time']

# %%
df_results.columns[3:].to_list()
# Out:
# ['test_accuracy',
#  'test_precision',
#  'test_recall',
#  'test_roc_auc',
#  'test_average_precision',
#  'time']

# %%
df_results_explode = df_results.explode(
    df_results.columns[1:].to_list()
).reset_index(drop=True)

df_results_explode
# Out:
#                      model  fit_time score_time test_accuracy test_precision  \
# 0          DummyClassifier  0.033787    0.01155      0.512472       0.154206
# 1          DummyClassifier  0.027079   0.011896      0.503401        0.14486
# 2          DummyClassifier  0.028743   0.014396      0.503401        0.14486
# 3          DummyClassifier   0.02851   0.011734      0.487528       0.126168
# 4          DummyClassifier  0.027422   0.014604      0.510204       0.149533
# 5   DecisionTreeClassifier  0.026254   0.011283      0.825397       0.432432
# 6   DecisionTreeClassifier  0.029907   0.011974      0.829932       0.444444
# 7   DecisionTreeClassifier   0.02817   0.012339      0.829932       0.448718
# 8   DecisionTreeClassifier  0.028181   0.011406      0.811791       0.402299
# 9   DecisionTreeClassifier  0.027205   0.012272      0.689342       0.267974
# 10      LogisticRegression  0.045392   0.016162       0.78458       0.351064
# 11      LogisticRegression   0.04645   0.014414      0.829932       0.444444
# 12      LogisticRegression  0.044828   0.016273      0.829932           0.45
# 13      LogisticRegression   0.04478   0.015754      0.814059       0.409091
# 14      LogisticRegression  0.037485   0.015408      0.836735       0.466667
# 15           KNNClassifier  0.026181    0.01449       0.85034       0.517241
# 16           KNNClassifier   0.03907   0.021728      0.852608       0.533333
# 17           KNNClassifier  0.038577   0.020885      0.854875       0.565217
# 18           KNNClassifier  0.041718   0.018903      0.875283       0.823529
# 19           KNNClassifier  0.040639   0.019784      0.736961       0.331081
#
#    test_recall test_roc_auc test_average_precision      time
# 0     0.492537      0.50429                0.15305  0.045336
# 1     0.462687     0.486691               0.148657  0.038975
# 2     0.462687     0.486691               0.148657  0.043139
# 3     0.409091     0.455212                0.14005  0.040244
# 4     0.484848     0.499758               0.149598  0.042027
# 5     0.477612      0.68535               0.368383  0.037537
# 6     0.477612     0.707738               0.380168   0.04188
# 7     0.522388     0.738267               0.360261  0.040509
# 8     0.530303     0.718303               0.431172  0.039588
# 9     0.621212     0.663313               0.226199  0.039477
# 10    0.492537     0.685709               0.381981  0.061554
# 11    0.477612     0.708317               0.415027  0.060863
# 12    0.537313     0.738586               0.363251  0.061101
# 13    0.545455     0.718889               0.409818  0.060534
# 14    0.636364     0.794768               0.506528  0.052893
# 15    0.223881     0.601305               0.283526  0.040671
# 16    0.238806     0.603001               0.301218  0.060797
# 17     0.19403     0.606174               0.252589  0.059462
# 18    0.212121     0.643717               0.363419  0.060622
# 19    0.742424     0.771778               0.379045  0.060423

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 8), tight_layout=True)
cols = df_results.columns[3:].to_list()

for ax, col in zip(axs.flatten(), cols):
    b = sns.boxplot(
        x="model", y=col, data=df_results_explode, ax=ax, showmeans=True,
        hue="model", palette="tab10", legend=False
    )
    ax.tick_params(axis='x', labelsize=7)

plt.show()
